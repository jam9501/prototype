# %%
import requests

# %%
import pandas as pd

# %%
import os
import csv

# %%
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/ainsleymartinez

# %%
df = '/Users/ainsleymartinez/Downloads/LEDE/Prez_ties.csv'

# %%
rows = []

# %%
import csv
data = '/Users/ainsleymartinez/Downloads/LEDE/Prez_ties.csv'
rows = []

with open(data, 'r', newline='') as csvfile:

    csvreader = csv.reader(csvfile)
    
    for row in csvreader:
        rows.append(row)
        
for row in rows:
    print(row)
# Out:
# ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c']
# ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four']
# ['', '', '1904', 'Alton B. Parker', 'Four']
# ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four']
# ['Woodrow Wilson', 'Pratt', '1912', '', '']
# ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four']
# ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four']
# ['', '', '1924', 'John W. Davis', 'Four']
# ['', '', '1924', 'Robert M. Lafollette', 'Four']
# ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four']
# ['Franklin D. Roosevelt', 'Four', '1928', '', '']
# ['', '', '1932', 'Norman Thomas', 'Four']
# ['', '', '1936', 'Alfred M. Landon', 'Four']
# ['', '', '1940', 'Wendell L. Willkie', 'Windsor']
# ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor']
# ['', '', '1948', 'J. Strom Thurmond', 'Windsor']
# ['', '', '1948', 'Henry A. Wallace', 'Windsor']
# ...

# %%
import pandas as pd
import numpy as np
data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [np.nan, np.nan, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', np.nan, np.nan],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [np.nan, np.nan, '1924', 'John W. Davis', 'Four'],
    [np.nan, np.nan, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', np.nan, np.nan],
    [np.nan, np.nan, '1932', 'Norman Thomas', 'Four'],
    [np.nan, np.nan, '1936', 'Alfred M. Landon', 'Four'],
    [np.nan, np.nan, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [np.nan, np.nan, '1948', 'J. Strom Thurmond', 'Windsor'],
    [np.nan, np.nan, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', np.nan, np.nan],
    ['Lyndon B. Johnson', 'Four', '1960', np.nan, np.nan],
    [np.nan, np.nan, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [np.nan, np.nan, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', np.nan, np.nan],
    [np.nan, np.nan, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [np.nan, np.nan, '1996', 'Robert J. Dole', 'Windsor'],
    [np.nan, np.nan, '2000', 'Albert Gore', 'Windsor'],
    [np.nan, np.nan, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [np.nan, np.nan, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', np.nan, np.nan]
]
df = pd.DataFrame(data[1:], columns=data[0])

df.replace('', np.nan, inplace=True)

most_common_knot = df['knot_p'].value_counts().idxmax()

print(f"The most common knot type is: {most_common_knot}")
# Out:
# The most common knot type is: Four

# %%
most_common_knot = df['knot_c'].value_counts().idxmax()

print(f"The most common knot type is: {most_common_knot}")
# Out:
# The most common knot type is: Windsor

# %%
least_common_knot = df['knot_p'].value_counts().idxmin()

print(f"The least common knot type is: {least_common_knot}")
# Out:
# The least common knot type is: Pratt

# %%
least_common_knot = df['knot_c'].value_counts().idxmin()

print(f"The least common knot type is: {least_common_knot}")
# Out:
# The least common knot type is: NA

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]


df = pd.DataFrame(data[1:], columns=data[0])


df.replace('', pd.NA, inplace=True)


knot_counts = df['knot_p'].value_counts()

# Plotting
plt.figure(figsize=(10, 6))
knot_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Presidents Wearing Each Tie Knot')
plt.xlabel('Tie Knot')
plt.ylabel('Number of Presidents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]

df = pd.DataFrame(data[1:], columns=data[0])

df.replace('', pd.NA, inplace=True)

party_mapping = {
    'William McKinley': 'Republican',
    'Alton B. Parker': 'Democratic',
    'William J. Bryan': 'Democratic',
    'Charles E. Hughes': 'Republican',
    'James M. Cox': 'Democratic',
    'John W. Davis': 'Democratic',
    'Robert M. Lafollette': 'Progressive',
    'Alfred E. Smith': 'Democratic',
    'Norman Thomas': 'Socialist',
    'Alfred M. Landon': 'Republican',
    'Wendell L. Willkie': 'Republican',
    'Thomas E. Dewey': 'Republican',
    'J. Strom Thurmond': 'Dixiecrat',
    'Henry A. Wallace': 'Progressive',
    'Adlai E. Stevenson': 'Democratic',
    'Barry M. Goldwater': 'Republican',
    'Hubert H. Humphrey': 'Democratic',
    'George C. Wallace': 'Independent',
    'George S. McGovern': 'Democratic',
    'John Anderson': 'Independent',
    'Walter F. Mondale': 'Democratic',
    'Michael Dukakis': 'Democratic',
    'H. Ross Perot': 'Independent',
    'Robert J. Dole': 'Republican',
    'Albert Gore': 'Democratic',
    'Ralph Nader': 'Green',
    'John Kerry': 'Democratic',
    'John McCain': 'Republican',
    'Mitt Romney': 'Republican',
    'Hillary Rodham Clinton': 'Democratic',
    'Joseph R. Biden': 'Democratic'
}

df['party'] = df['canidate'].map(party_mapping)

# %%
# Out:
# 0      Republican
# 1      Democratic
# 2      Democratic
# 3             NaN
# 4      Republican
# 5      Democratic
# 6      Democratic
# 7     Progressive
# 8      Democratic
# 9             NaN
# 10      Socialist
# 11     Republican
# 12     Republican
# 13     Republican
# 14      Dixiecrat
# 15    Progressive
# 16     Democratic
# 17            NaN
# 18            NaN
# 19     Republican
# 20     Democratic
# 21    Independent
# 22     Democratic
# 23            NaN
# 24    Independent
# 25     Democratic
# 26     Democratic
# 27    Independent
# 28     Republican
# 29     Democratic
# 30          Green
# 31     Democratic
# 32     Republican
# 33     Republican
# 34     Democratic
# 35            NaN
# Name: party, dtype: object

# %%
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]

df = pd.DataFrame(data[1:], columns=data[0])


df.replace('', pd.NA, inplace=True)


party_mapping = {
    'William McKinley': 'Republican',
    'Alton B. Parker': 'Democratic',
    'William J. Bryan': 'Democratic',
    'Charles E. Hughes': 'Republican',
    'James M. Cox': 'Democratic',
    'John W. Davis': 'Democratic',
    'Robert M. Lafollette': 'Progressive',
    'Alfred E. Smith': 'Democratic',
    'Norman Thomas': 'Socialist',
    'Alfred M. Landon': 'Republican',
    'Wendell L. Willkie': 'Republican',
    'Thomas E. Dewey': 'Republican',
    'J. Strom Thurmond': 'Dixiecrat',
    'Henry A. Wallace': 'Progressive',
    'Adlai E. Stevenson': 'Democratic',
    'Barry M. Goldwater': 'Republican',
    'Hubert H. Humphrey': 'Democratic',
    'George C. Wallace': 'Independent',
    'George S. McGovern': 'Democratic',
    'John Anderson': 'Independent',
    'Walter F. Mondale': 'Democratic',
    'Michael Dukakis': 'Democratic',
    'H. Ross Perot': 'Independent',
    'Robert J. Dole': 'Republican',
    'Albert Gore': 'Democratic',
    'Ralph Nader': 'Green',
    'John Kerry': 'Democratic',
    'John McCain': 'Republican',
    'Mitt Romney': 'Republican',
    'Hillary Rodham Clinton': 'Democratic',
    'Joseph R. Biden': 'Democratic'
}


df['party'] = df['canidate'].map(party_mapping)


party_counts = df.groupby('knot_p')['party'].value_counts().unstack(fill_value=0)


plt.figure(figsize=(10, 6))
party_counts.plot(kind='bar', stacked=True, colormap='tab20', ax=plt.gca())
plt.title('Tie Knots Worn by Presidents, Split by Political Party')
plt.xlabel('Tie Knot')
plt.ylabel('Number of Presidents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend(title='Party', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]


df = pd.DataFrame(data[1:], columns=data[0])


df.replace('', pd.NA, inplace=True)


party_mapping = {
    'William McKinley': 'Republican',
    'Alton B. Parker': 'Democratic',
    'William J. Bryan': 'Democratic',
    'Charles E. Hughes': 'Republican',
    'James M. Cox': 'Democratic',
    'John W. Davis': 'Democratic',
    'Robert M. Lafollette': 'Progressive',
    'Alfred E. Smith': 'Democratic',
    'Norman Thomas': 'Socialist',
    'Alfred M. Landon': 'Republican',
    'Wendell L. Willkie': 'Republican',
    'Thomas E. Dewey': 'Republican',
    'J. Strom Thurmond': 'Dixiecrat',
    'Henry A. Wallace': 'Progressive',
    'Adlai E. Stevenson': 'Democratic',
    'Barry M. Goldwater': 'Republican',
    'Hubert H. Humphrey': 'Democratic',
    'George C. Wallace': 'Independent',
    'George S. McGovern': 'Democratic',
    'John Anderson': 'Independent',
    'Walter F. Mondale': 'Democratic',
    'Michael Dukakis': 'Democratic',
    'H. Ross Perot': 'Independent',
    'Robert J. Dole': 'Republican',
    'Albert Gore': 'Democratic',
    'Ralph Nader': 'Green',
    'John Kerry': 'Democratic',
    'John McCain': 'Republican',
    'Mitt Romney': 'Republican',
    'Hillary Rodham Clinton': 'Democratic',
    'Joseph R. Biden': 'Democratic'
}


df['party'] = df['canidate'].map(party_mapping)


df_filtered = df[df['knot_p'].isin(['Windsor', 'Four'])]


party_counts = df_filtered.groupby(['knot_p', 'knot_c'])['party'].value_counts().unstack(fill_value=0)


plt.figure(figsize=(10, 6))

colors = {'Democratic': 'blue', 'Republican': 'red', 'Independent': 'brown'}


bar_width = 0.35  
bar_padding = 0.05  


bottom = None
for i, party in enumerate(party_counts.columns):
    plt.bar(np.arange(len(party_counts.index.get_level_values('knot_p'))) + i * (bar_width + bar_padding), party_counts[party], 
            width=bar_width, label=party, color=colors.get(party, 'gray'))

plt.title('Tie Knots Worn by Presidents (Windsor and Four), Split by Political Party')
plt.xlabel('Tie Knot (Primary and Secondary)')
plt.ylabel('Number of Presidents')

plt.xticks(ticks=np.arange(len(party_counts.index.get_level_values('knot_p'))) + (len(party_counts.columns) - 1) * (bar_width + bar_padding) / 2, 
           labels=party_counts.index.get_level_values('knot_p'))

plt.legend(title='Party', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]


df = pd.DataFrame(data[1:], columns=data[0])


df.replace('', pd.NA, inplace=True)

party_mapping = {
    'William McKinley': 'Republican',
    'Alton B. Parker': 'Democratic',
    'William J. Bryan': 'Democratic',
    'Charles E. Hughes': 'Republican',
    'James M. Cox': 'Democratic',
    'John W. Davis': 'Democratic',
    'Robert M. Lafollette': 'Progressive',
    'Alfred E. Smith': 'Democratic',
    'Norman Thomas': 'Socialist',
    'Alfred M. Landon': 'Republican',
    'Wendell L. Willkie': 'Republican',
    'Thomas E. Dewey': 'Republican',
    'J. Strom Thurmond': 'Dixiecrat',
    'Henry A. Wallace': 'Progressive',
    'Adlai E. Stevenson': 'Democratic',
    'Barry M. Goldwater': 'Republican',
    'Hubert H. Humphrey': 'Democratic',
    'George C. Wallace': 'Independent',
    'George S. McGovern': 'Democratic',
    'John Anderson': 'Independent',
    'Walter F. Mondale': 'Democratic',
    'Michael Dukakis': 'Democratic',
    'H. Ross Perot': 'Independent',
    'Robert J. Dole': 'Republican',
    'Albert Gore': 'Democratic',
    'Ralph Nader': 'Green',
    'John Kerry': 'Democratic',
    'John McCain': 'Republican',
    'Mitt Romney': 'Republican',
    'Hillary Rodham Clinton': 'Democratic',
    'Joseph R. Biden': 'Democratic'
}


df['party'] = df['canidate'].map(party_mapping)


df_filtered = df[df['knot_p'].isin(['Four', 'Windsor']) | df['knot_c'].isin(['Four', 'Windsor'])]

four_knot_p_counts = df_filtered[df_filtered['knot_p'] == 'Four'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)
windsor_knot_p_counts = df_filtered[df_filtered['knot_p'] == 'Windsor'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)
four_knot_c_counts = df_filtered[df_filtered['knot_c'] == 'Four'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)
windsor_knot_c_counts = df_filtered[df_filtered['knot_c'] == 'Windsor'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)


plt.figure(figsize=(10, 6))


colors = {
    'Democratic': 'blue',
    'Republican': 'red',
    'Independent': 'brown',
    'Progressive': 'green',
    'Socialist': 'orange',
    'Dixiecrat': 'purple',
    'Green': 'green'
}

bar_width = 0.2
index = df['party'].unique()
ind = range(len(index))


plt.barh(ind, four_knot_p_counts, bar_width, label='Four knots_p', color=[colors.get(party, 'gray') for party in index])
plt.barh(ind, windsor_knot_p_counts, bar_width, left=four_knot_p_counts, label='Windsor knots_p', color=[colors.get(party, 'gray') for party in index])
plt.barh(ind, four_knot_c_counts, bar_width, left=four_knot_p_counts + windsor_knot_p_counts, label='Four knots_c', color=[colors.get(party, 'gray') for party in index])
plt.barh(ind, windsor_knot_c_counts, bar_width, left=four_knot_p_counts + windsor_knot_p_counts + four_knot_c_counts, label='Windsor knots_c', color=[colors.get(party, 'gray') for party in index])


plt.yticks(ind, index)
plt.xlabel('Number of Presidents')
plt.ylabel('Political Party')
plt.title('Tie Knots Worn by Presidents (Four and Windsor), Split by Political Party')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]


df = pd.DataFrame(data[1:], columns=data[0])

df.replace('', pd.NA, inplace=True)

party_mapping = {
    'William McKinley': 'Republican',
    'Alton B. Parker': 'Democratic',
    'William J. Bryan': 'Democratic',
    'Charles E. Hughes': 'Republican',
    'James M. Cox': 'Democratic',
    'John W. Davis': 'Democratic',
    'Robert M. Lafollette': 'Progressive',
    'Alfred E. Smith': 'Democratic',
    'Norman Thomas': 'Socialist',
    'Alfred M. Landon': 'Republican',
    'Wendell L. Willkie': 'Republican',
    'Thomas E. Dewey': 'Republican',
    'J. Strom Thurmond': 'Dixiecrat',
    'Henry A. Wallace': 'Progressive',
    'Adlai E. Stevenson': 'Democratic',
    'Barry M. Goldwater': 'Republican',
    'Hubert H. Humphrey': 'Democratic',
    'George C. Wallace': 'Independent',
    'George S. McGovern': 'Democratic',
    'John Anderson': 'Independent',
    'Walter F. Mondale': 'Democratic',
    'Michael Dukakis': 'Democratic',
    'H. Ross Perot': 'Independent',
    'Robert J. Dole': 'Republican',
    'Albert Gore': 'Democratic',
    'Ralph Nader': 'Green',
    'John Kerry': 'Democratic',
    'John McCain': 'Republican',
    'Mitt Romney': 'Republican',
    'Hillary Rodham Clinton': 'Democratic',
    'Joseph R. Biden': 'Democratic'
}

df['party'] = df['canidate'].map(party_mapping)

df_filtered = df[df['knot_p'].isin(['Four', 'Windsor']) | df['knot_c'].isin(['Four', 'Windsor'])]

four_knot_p_counts = df_filtered[df_filtered['knot_p'] == 'Four'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)
windsor_knot_p_counts = df_filtered[df_filtered['knot_p'] == 'Windsor'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)
four_knot_c_counts = df_filtered[df_filtered['knot_c'] == 'Four'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)
windsor_knot_c_counts = df_filtered[df_filtered['knot_c'] == 'Windsor'].groupby('party').size().reindex(df['party'].unique(), fill_value=0)


plt.figure(figsize=(10, 6))

colors = {
    'Democratic': 'blue',
    'Republican': 'red',
    'Independent': 'brown',
    'Progressive': 'green',
    'Socialist': 'orange',
    'Dixiecrat': 'purple',
    'Green': 'green'
}

bar_width = 0.4
index = df['party'].unique()
ind = range(len(index))


plt.barh(ind, four_knot_p_counts, bar_width, label='Four knots_p', color=colors['Democratic'])
plt.barh(ind, windsor_knot_p_counts, bar_width, left=four_knot_p_counts, label='Windsor knots_p', color=colors['Republican'])
plt.barh(ind, four_knot_c_counts, bar_width, left=four_knot_p_counts + windsor_knot_p_counts, label='Four knots_c', color=colors['Independent'])
plt.barh(ind, windsor_knot_c_counts, bar_width, left=four_knot_p_counts + windsor_knot_p_counts + four_knot_c_counts, label='Windsor knots_c', color=colors['Progressive'])

plt.yticks(ind, index)
plt.xlabel('Number of Presidents')
plt.title('Counts of Windsor and Four Knots in Knot_p and Knot_c')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = [
    ['\ufeffpresident', 'knot_p', 'year', 'canidate', 'knot_c'],
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]


df = pd.DataFrame(data[1:], columns=data[0])


df.replace('', pd.NA, inplace=True)


four_knot_p_count = df[df['knot_p'] == 'Four'].shape[0]
windsor_knot_p_count = df[df['knot_p'] == 'Windsor'].shape[0]
four_knot_c_count = df[df['knot_c'] == 'Four'].shape[0]
windsor_knot_c_count = df[df['knot_c'] == 'Windsor'].shape[0]


colors = {
    'Democratic': 'blue',
    'Republican': 'red',
    'Green': 'brown',  # Example for other parties; you can add more colors as needed
}

fig, ax = plt.subplots(figsize=(10, 6))

ind = [1, 2, 3, 4]
bar_width = 0.4

four_knot_p = [four_knot_p_count, 0, 0, 0]  # Four knots in knot_p
windsor_knot_p = [0, windsor_knot_p_count, 0, 0]  # Windsor knots in knot_p
four_knot_c = [0, 0, four_knot_c_count, 0]  # Four knots in knot_c
windsor_knot_c = [0, 0, 0, windsor_knot_c_count]  # Windsor knots in knot_c

bars1 = ax.barh(ind, four_knot_p, bar_width, color=colors['Democratic'], label='Four Knots in knot_p')
bars2 = ax.barh(ind, windsor_knot_p, bar_width, left=four_knot_p, color=colors['Republican'], label='Windsor Knots in knot_p')
bars3 = ax.barh(ind, four_knot_c, bar_width, left=[x + y for x, y in zip(four_knot_p, windsor_knot_p)], color=colors['Green'], label='Four Knots in knot_c')
bars4 = ax.barh(ind, windsor_knot_c, bar_width, left=[x + y + z for x, y, z in zip(four_knot_p, windsor_knot_p, four_knot_c)], color='brown', label='Windsor Knots in knot_c')

# Customize plot
ax.set_yticks(ind)
ax.set_yticklabels(['Four knot_p', 'Windsor knot_p', 'Four knot_c', 'Windsor knot_c'])
ax.set_xlabel('Count')
ax.set_title('Counts of Knots by Type and Knot')
ax.legend()

plt.show()

# %%
import pandas as pd

data = [
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]

columns = ['president', 'knots_p', 'knots_c_year', 'candidate', 'knots_c']
df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#                 president        knots_p knots_c_year               candidate  \
# 0      Theodore Roosevelt           Four         1900        William McKinley
# 1                    <NA>           <NA>         1904         Alton B. Parker
# 2         William H. Taft           Four         1908        William J. Bryan
# 3          Woodrow Wilson          Pratt         1912                    <NA>
# 4       Warren G. Harding           Four         1916       Charles E. Hughes
# 5         Calvin Coolidge           Four         1920            James M. Cox
# 6                    <NA>           <NA>         1924           John W. Davis
# 7                    <NA>           <NA>         1924    Robert M. Lafollette
# 8          Herbert Hoover           Four         1928         Alfred E. Smith
# 9   Franklin D. Roosevelt           Four         1928                    <NA>
# 10                   <NA>           <NA>         1932           Norman Thomas
# ...

# %%
import pandas as pd

data = [
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]

columns = ['president', 'knots_p', 'knots_c_year', 'candidate', 'knots_c']
df = pd.DataFrame(data, columns=columns)

party_mapping = {
    'Theodore Roosevelt': 'Republican',
    'William McKinley': 'Republican',
    'Alton B. Parker': 'Democratic',
    'William J. Bryan': 'Democratic',
    'Charles E. Hughes': 'Republican',
    'James M. Cox': 'Democratic',
    'John W. Davis': 'Democratic',
    'Robert M. Lafollette': 'Republican',
    'Herbert Hoover': 'Republican',
    'Alfred E. Smith': 'Democratic',
    'Franklin D. Roosevelt': 'Democratic',
    'Norman Thomas': 'Socialist',
    'Alfred M. Landon': 'Republican',
    'Wendell L. Willkie': 'Republican',
    'Harry S. Truman': 'Democratic',
    'Thomas E. Dewey': 'Republican',
    'J. Strom Thurmond': 'Democratic',
    'Henry A. Wallace': 'Democratic',
    'Dwight D. Eisenhower': 'Republican',
    'Adlai E. Stevenson': 'Democratic',
    'John F. Kennedy': 'Democratic',
    'Lyndon B. Johnson': 'Democratic',
    'Barry M. Goldwater': 'Republican',
    'Richard M. Nixon': 'Republican',
    'Hubert H. Humphrey': 'Democratic',
    'George C. Wallace': 'Democratic',
    'George S. McGovern': 'Democratic',
    'Jimmy Carter': 'Democratic',
    'John Anderson': 'Republican',
    'Walter F. Mondale': 'Democratic',
    'Michael Dukakis': 'Democratic',
    'Bill Clinton': 'Democratic',
    'H. Ross Perot': 'Independent',
    'Robert J. Dole': 'Republican',
    'Albert Gore': 'Democratic',
    'Ralph Nader': 'Green',
    'George W. Bush': 'Republican',
    'John Kerry': 'Democratic',
    'Barack Obama': 'Democratic',
    'John McCain': 'Republican',
    'Mitt Romney': 'Republican',
    'Donald J. Trump': 'Republican',
    'Hillary Rodham Clinton': 'Democratic',
    'Joseph R. Biden': 'Democratic'
}


df['party'] = df['president'].map(party_mapping)

democrats_windsor = df[(df['knots_c'] == 'Windsor') & (df['party'] == 'Democratic')]

total_windsor = len(df[df['knots_c'] == 'Windsor'])
percentage_democrats_windsor = (len(democrats_windsor) / total_windsor) * 100

print(f"Percentage of Democrats who wore a Windsor knot: {percentage_democrats_windsor:.2f}%")
# Out:
# Percentage of Democrats who wore a Windsor knot: 15.79%

# %%
import pandas as pd

# Original data
data = [
    ['Theodore Roosevelt', 'Four', '1900', 'William McKinley', 'Four'],
    [pd.NA, pd.NA, '1904', 'Alton B. Parker', 'Four'],
    ['William H. Taft', 'Four', '1908', 'William J. Bryan', 'Four'],
    ['Woodrow Wilson', 'Pratt', '1912', pd.NA, pd.NA],
    ['Warren G. Harding', 'Four', '1916', 'Charles E. Hughes', 'Four'],
    ['Calvin Coolidge', 'Four', '1920', 'James M. Cox', 'Four'],
    [pd.NA, pd.NA, '1924', 'John W. Davis', 'Four'],
    [pd.NA, pd.NA, '1924', 'Robert M. Lafollette', 'Four'],
    ['Herbert Hoover', 'Four', '1928', 'Alfred E. Smith', 'Four'],
    ['Franklin D. Roosevelt', 'Four', '1928', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1932', 'Norman Thomas', 'Four'],
    [pd.NA, pd.NA, '1936', 'Alfred M. Landon', 'Four'],
    [pd.NA, pd.NA, '1940', 'Wendell L. Willkie', 'Windsor'],
    ['Harry S. Truman', 'Four', '1944', 'Thomas E. Dewey', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'J. Strom Thurmond', 'Windsor'],
    [pd.NA, pd.NA, '1948', 'Henry A. Wallace', 'Windsor'],
    ['Dwight D. Eisenhower', 'Windsor', '1952', 'Adlai E. Stevenson', 'Windsor'],
    ['John F. Kennedy', 'Small four', '1956', pd.NA, pd.NA],
    ['Lyndon B. Johnson', 'Four', '1960', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1964', 'Barry M. Goldwater', 'Windsor'],
    ['Richard M. Nixon', 'Large four', '1968', 'Hubert H. Humphrey', 'Windsor'],
    [pd.NA, pd.NA, '1968', 'George C. Wallace', 'Windsor'],
    ['Gerald R. Ford', 'Four', '1972', 'George S. McGovern', 'Windsor'],
    ['Jimmy Carter', 'Four', '1976', pd.NA, pd.NA],
    [pd.NA, pd.NA, '1980', 'John Anderson', 'Windsor'],
    ['Ronald Reagan', 'Four', '1984', 'Walter F. Mondale', 'Windsor'],
    ['George H. W. Bush', 'Four', '1988', 'Michael Dukakis', 'Windsor'],
    ['Bill Clinton', 'Large Windsor', '1992', 'H. Ross Perot', 'Windsor'],
    [pd.NA, pd.NA, '1996', 'Robert J. Dole', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Albert Gore', 'Windsor'],
    [pd.NA, pd.NA, '2000', 'Ralph Nader', 'Windsor'],
    ['George W. Bush', 'Full Windsor', '2004', 'John Kerry', 'Windsor'],
    ['Barack Obama', 'Large Four', '2008', 'John McCain', 'Windsor'],
    [pd.NA, pd.NA, '2012', 'Mitt Romney', 'Windsor'],
    ['Donald J. Trump', 'Large Windsor', '2016', 'Hillary Rodham Clinton', 'NA'],
    ['Joseph R. Biden', 'Large Four', '2020', pd.NA, pd.NA]
]

columns = ['president', 'knots_p', 'knots_c_year', 'candidate', 'knots_c']
df = pd.DataFrame(data, columns=columns)

# Dictionary to map candidate names to parties
party_mapping = {
    'Theodore Roosevelt': 'Republican',
    'William McKinley': 'Republican',
    'Alton B. Parker': 'Democratic',
    'William J. Bryan': 'Democratic',
    'Charles E. Hughes': 'Republican',
    'James M. Cox': 'Democratic',
    'John W. Davis': 'Democratic',
    'Robert M. Lafollette': 'Republican',
    'Herbert Hoover': 'Republican',
    'Alfred E. Smith': 'Democratic',
    'Franklin D. Roosevelt': 'Democratic',
    'Norman Thomas': 'Socialist',
    'Alfred M. Landon': 'Republican',
    'Wendell L. Willkie': 'Republican',
    'Harry S. Truman': 'Democratic',
    'Thomas E. Dewey': 'Republican',
    'J. Strom Thurmond': 'Democratic',
    'Henry A. Wallace': 'Democratic',
    'Dwight D. Eisenhower': 'Republican',
    'Adlai E. Stevenson': 'Democratic',
    'John F. Kennedy': 'Democratic',
    'Lyndon B. Johnson': 'Democratic',
    'Barry M. Goldwater': 'Republican',
    'Richard M. Nixon': 'Republican',
    'Hubert H. Humphrey': 'Democratic',
    'George C. Wallace': 'Democratic',
    'George S. McGovern': 'Democratic',
    'Jimmy Carter': 'Democratic',
    'John Anderson': 'Republican',
    'Walter F. Mondale': 'Democratic',
    'Michael Dukakis': 'Democratic',
    'Bill Clinton': 'Democratic',
    'H. Ross Perot': 'Independent',
    'Robert J. Dole': 'Republican',
    'Albert Gore': 'Democratic',
    'Ralph Nader': 'Green',
    'George W. Bush': 'Republican',
    'John Kerry': 'Democratic',
    'Barack Obama': 'Democratic',
    'John McCain': 'Republican',
    'Mitt Romney': 'Republican',
    'Donald J. Trump': 'Republican',
    'Hillary Rodham Clinton': 'Democratic',
    'Joseph R. Biden': 'Democratic'
}

party_mapping_df = pd.DataFrame(list(party_mapping.items()), columns=['candidate', 'party'])

merged_df = pd.merge(df, party_mapping_df, on='candidate', how='left')

print(merged_df)
# Out:
#                 president        knots_p knots_c_year               candidate  \
# 0      Theodore Roosevelt           Four         1900        William McKinley
# 1                    <NA>           <NA>         1904         Alton B. Parker
# 2         William H. Taft           Four         1908        William J. Bryan
# 3          Woodrow Wilson          Pratt         1912                    <NA>
# 4       Warren G. Harding           Four         1916       Charles E. Hughes
# 5         Calvin Coolidge           Four         1920            James M. Cox
# 6                    <NA>           <NA>         1924           John W. Davis
# 7                    <NA>           <NA>         1924    Robert M. Lafollette
# 8          Herbert Hoover           Four         1928         Alfred E. Smith
# 9   Franklin D. Roosevelt           Four         1928                    <NA>
# 10                   <NA>           <NA>         1932           Norman Thomas
# ...

# %%
import pandas as pd


total_windsor_candidates = merged_df[merged_df['knots_c'] == 'Windsor'].shape[0]

republican_windsor_df = merged_df[(merged_df['knots_c'] == 'Windsor') & (merged_df['party'] == 'Democratic')]

republican_windsor_count = republican_windsor_df.shape[0]

if total_windsor_candidates > 0:
    percentage_republican_windsor = (republican_windsor_count / total_windsor_candidates) * 100
else:
    percentage_republican_windsor = 0.0  # Handle division by zero scenario

print(f"Percentage of Unsuccessful Democrats who wore a Windsor knot: {percentage_republican_windsor:.2f}%")
# Out:
# Percentage of Unsuccessful Democrats who wore a Windsor knot: 52.63%

# %%
total_windsor_candidates = merged_df[merged_df['knots_c'] == 'Windsor'].shape[0]

republican_windsor_df = merged_df[(merged_df['knots_c'] == 'Windsor') & (merged_df['party'] == 'Republican')]

republican_windsor_count = republican_windsor_df.shape[0]

if total_windsor_candidates > 0:
    percentage_republican_windsor = (republican_windsor_count / total_windsor_candidates) * 100
else:
    percentage_republican_windsor = 0.0  

print(f"Percentage of Unsuccessful Republicans who wore a Windsor knot: {percentage_republican_windsor:.2f}%")
# Out:
# Percentage of Unsuccessful Republicans who wore a Windsor knot: 36.84%

# %%
total_windsor_candidates = merged_df[merged_df['knots_c'] == 'Four'].shape[0]

republican_windsor_df = merged_df[(merged_df['knots_c'] == 'Four') & (merged_df['party'] == 'Republican')]

republican_windsor_count = republican_windsor_df.shape[0]

if total_windsor_candidates > 0:
    percentage_republican_windsor = (republican_windsor_count / total_windsor_candidates) * 100
else:
    percentage_republican_windsor = 0.0  # Handle division by zero scenario

print(f"Percentage of Unsuccessful Republicans who wore a Four knot: {percentage_republican_windsor:.2f}%")
# Out:
# Percentage of Unsuccessful Republicans who wore a Four knot: 40.00%

# %%
import pandas as pd

total_windsor_candidates = merged_df[merged_df['knots_c'] == 'Four'].shape[0]

republican_windsor_df = merged_df[(merged_df['knots_c'] == 'Four') & (merged_df['party'] == 'Democratic')]

republican_windsor_count = republican_windsor_df.shape[0]

if total_windsor_candidates > 0:
    percentage_republican_windsor = (republican_windsor_count / total_windsor_candidates) * 100
else:
    percentage_republican_windsor = 0.0  # Handle division by zero scenario

print(f"Percentage of Unsuccessful Republicans who wore a Four knot: {percentage_republican_windsor:.2f}%")
# Out:
# Percentage of Unsuccessful Republicans who wore a Four knot: 50.00%
